# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AnshGarg13622/FlyRank_Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# I choose **Lane 2: Refresh / Content Opportunity Scoring** because it focuses on identifying which web pages have the greatest potential for improvement through content updates. My goal is to build a scoring system that ranks pages based on their search performance, impressions, and other relevant signals. This will help editors decide which pages should be reviewed and refreshed first, instead of relying on guesswork. I am interested in this lane because it combines data analysis, machine learning, and practical decision-making. The final output will be a ranked review queue with scores, recommended actions, and reason codes to support efficient content optimisation.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# ####**Research Question:**
#
# Which pages should be prioritised for content refresh?
#
# ####**Decision:**
#
# Select pages with the highest opportunity scores.
#
# ####**Action:**
#
# Editors update content.
#
# ####**Cost of Wrong Recommendation:**
#
# Wasted editing time and missed traffic opportunities.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# !git clone https://github.com/AnshGarg13622/FlyRank_Internship.git
# Out:
# Cloning into 'FlyRank_Internship'...
# remote: Enumerating objects: 118, done.
# remote: Counting objects: 100% (118/118), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 118 (delta 31), reused 98 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (118/118), 1.86 MiB | 13.33 MiB/s, done.
# Resolving deltas: 100% (31/31), done.

# %%
# %cd FlyRank_Internship
# Out:
# /content/FlyRank_Internship

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

declining_rate = (
    df["trend_direction"].str.lower().eq("down").mean()
)

print("Number of pages:", len(df))
print("Median impressions_90d:", round(df["impressions_90d"].median(), 1))
print("Declining rate:", round(declining_rate * 100, 1), "%")
# Out:
# Number of pages: 30000
# Median impressions_90d: 731.0
# Declining rate: 54.2 %

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# #### **What I can claim**
#
# * I can identify pages with content-refresh opportunities using search and performance data.
# * I can provide directional insights and ranked recommendations to help editors prioritise their work.
#
# #### **What I cannot claim**
#
# * I cannot prove that refreshing content will directly increase traffic or rankings.
# * I cannot predict Google’s ranking algorithm or guarantee future search performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
